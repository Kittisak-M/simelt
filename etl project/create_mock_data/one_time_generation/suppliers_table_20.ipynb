# %%
from faker import Faker
import pandas as pd

fake = Faker()

def generate_fake_supplier_data(num_records):
    supplier_data = []
    
    for _ in range(num_records):
        supplier = {
            'supplier_name': fake.company(),
            'contact_name': fake.name(),
            'contact_email': fake.email(),
            'contact_phone': fake.phone_number(),
            'address': fake.address(),
            'city': fake.city(),
            'country': fake.country()
        }
        supplier_data.append(supplier)
    
    return supplier_data

suppliers = generate_fake_supplier_data(20)
suppliers_df = pd.DataFrame(suppliers)
# Out:
#                   supplier_name           contact_name  \
# 0                  Espinoza Inc          Mathew Thomas
# 1      Smith, Stanton and Henry          Abigail Jones
# 2                   Miles Group         Samantha Singh
# 3                     Smith Inc              Tony Lane
# 4                Lopez and Sons          Daniel Turner
# 5                 Gutierrez Ltd     Stephen Sanders MD
# 6                  Griffin-Wolf        James Alexander
# 7                Wallace-Garcia           Jesus Hansen
# 8      Walsh, Bush and Campbell        Melinda Bennett
# 9                    West Group         Stephen Turner
# 10             Burgess and Sons          Christy Black
# 11     Graham, Ashley and Moore             Gary Bowen
# 12               Beard and Sons         Maria Williams
# 13     Young, Gonzalez and Wang            Wanda Riggs
# 14               Rogers-Barnett         Peter Fletcher
# 15  Ramirez, Carlson and Warren         April Gallegos
# 16                    Mason Inc            Bryan Smith
# 17                  Pratt Group          Stephen Clark
# 18                 Hart-Estrada  Christina Padilla PhD
# 19                   Wilson Ltd           Tiffany Moss
#
#                   contact_email         contact_phone  \
# 0      douglasmolly@example.org    870-395-1516x03687
# 1        meganayers@example.com     (390)649-9620x015
# 2         theresa06@example.org            9955289708
# 3      powellandrea@example.org   +1-686-296-6551x337
# 4   gonzalezdeborah@example.net     762-627-6662x6549
# 5   katherinevargas@example.com   +1-847-281-0445x718
# 6       rebekahreed@example.com   (360)992-3312x45866
# 7          kristy40@example.com       +1-825-231-9798
# 8       calvinlewis@example.com   +1-373-502-4408x835
# 9              qlee@example.net          749.226.3443
# 10         brooke80@example.com    666.742.8820x64942
# 11         ricejohn@example.net     256.404.5153x1655
# 12    michaelpotter@example.com         (552)638-0922
# 13          khardin@example.com  001-598-918-6907x162
# 14     lisahumphrey@example.com      975-942-5971x128
# 15         mlambert@example.net          368.640.6922
# 16        zrichards@example.net      298.904.7914x199
# 17         cnielsen@example.net      897.446.3625x548
# 18        brownlisa@example.net      657.216.7013x525
# 19          peter85@example.org   (239)303-5228x83174
#
#                                               address              city  \
# 0   2232 Mcdonald Village Suite 483\nEast Angelvie...         Ericaside
# 1         441 Murphy Throughway\nDannymouth, ME 74263      Sullivanberg
# 2   50408 Tucker Mount Apt. 094\nEast Justin, AK 9...      Griffinville
# 3      33873 Ward Walk Apt. 664\nLake Jason, NC 05779  Lake Crystalview
# 4    0681 Daniel Valley Apt. 411\nKingmouth, WY 74422       Simmonsstad
# 5        551 Thompson Via\nEast Natalieview, IL 21794         Karenfort
# 6                    Unit 0161 Box 5522\nDPO AP 48933     North Heather
# 7        60177 Christensen Mews\nPort Megan, LA 43393     North William
# 8                    Unit 3768 Box 6331\nDPO AE 28866       Lake Amanda
# 9    88338 David Dam Suite 682\nPort Daniel, NC 01709        Lake Raven
# 10  802 Rice Centers Suite 536\nWest Margaretfort,...          Toddfurt
# 11    18216 Smith Turnpike\nNorth Brianstad, AL 08320        Tammieport
# 12                         USCGC Davila\nFPO AP 72654       Sierramouth
# 13  788 James Locks Apt. 125\nNorth Christian, KS ...   Christopherstad
# 14  6627 Elizabeth Terrace Suite 007\nRhodesshire,...        Floresview
# 15  23472 Nicholas Lock Suite 707\nWilsonfort, WV ...     New Reneeside
# 16        4376 Michelle Corners\nMillerside, MI 89660     North Michael
# 17                   PSC 8083, Box 5209\nAPO AA 02961       Brooksburgh
# 18                   PSC 6408, Box 7583\nAPO AE 24802  Port Zacharyview
# 19  6383 Turner Center Suite 818\nJohnmouth, MN 46130      New Victoria
#
#                                          country
# 0                                           Cuba
# 1                                          Ghana
# 2                                        Austria
# 3                                          Malta
# 4                                         Guinea
# 5                               Pitcairn Islands
# 6                                Kyrgyz Republic
# 7                                          Malta
# 8                                         Monaco
# 9                                        Vietnam
# 10                                    Costa Rica
# 11                                       Denmark
# 12                                      Bulgaria
# 13  South Georgia and the South Sandwich Islands
# 14                     Saint Pierre and Miquelon
# 15                                          Togo
# 16                                         Gabon
# 17                                          Chad
# 18                                          Togo
# 19                        Bosnia and Herzegovina
